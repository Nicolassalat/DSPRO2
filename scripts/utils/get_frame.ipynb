# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), "..", "env"))
from dolphin_capture import DolphinCapture

# %%
p1 = DolphinCapture(player_id=1)
p2 = DolphinCapture(player_id=2)
# Out:
# [DolphinCapture] Player 1 ready.
# [DolphinCapture] Player 2 ready.

# %%
p1()
# Out:
# <PIL.Image.Image image mode=L size=140x114>
# [DolphinCapture] Player 1 capture ended.[DolphinCapture] Player 2 capture ended.

# %%
p2()
# Out:
# <PIL.Image.Image image mode=L size=140x114>
